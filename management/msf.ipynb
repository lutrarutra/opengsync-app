# %%
import pickle

# %%
msf = pickle.load(open("/Users/agynter/Downloads/fb712880-c755-432d-8bcc-ec87ef4496a3.msf", "rb"))
msf
# Out:
# INFO @ 2025-07-14 13:54:39 (__init__.py:78 in <module>):
# >   Sample submission window: Wednesday 15:00:00 - 17:00:00
# INFO @ 2025-07-14 13:54:39 (__init__.py:78 in <module>):
# >   Sample submission window: Friday 13:00:00 - 15:00:00
# {'header': {'workflow': 'library_annotation',
#   'timestamp': '2025-07-14 13:40:16'},
#  'project_select': StepFile(args={'workflow_type': 'pooled'}, metadata={'project_name': 'Effect of a treatment on mouse CDX syngenic model', 'workflow': 'library_annotation', 'workflow_type': 'pooled', 'project_id': None, 'seq_request_id': 1, 'user_id': 3, 'project_description': 'Compared transcriptomic of treated CDX vs control\n'}, tables={}),
# ...

# %%
msf.keys()
# Out:
# dict_keys(['header', 'project_select', 'pooled_library_annotation', 'pool_mapping', 'barcode_input', 'index_kit_mapping', 'flex_annotation', 'sample_attribute_annotation', 'complete_sas'])

# %%
msf["complete_sas"].tables["sample_pooling_table"]
# Out:
#   sample_name                library_name      sample_pool mux_barcode  \
# 0        3671  CDX_Melanoma_EC_10XFLEXGEX  CDX_Melanoma_EC       BC001
# 1        3672  CDX_Melanoma_EC_10XFLEXGEX  CDX_Melanoma_EC       BC002
# 2        3709  CDX_Melanoma_EC_10XFLEXGEX  CDX_Melanoma_EC       BC003
# 3        3710  CDX_Melanoma_EC_10XFLEXGEX  CDX_Melanoma_EC       BC004
#
#    mux_type_id
# 0            3
# 1            3
# 2            3
# 3            3
